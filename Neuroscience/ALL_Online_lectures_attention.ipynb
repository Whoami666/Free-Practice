# %% [markdown]
# <a href="https://colab.research.google.com/github/Whoami666/Free-Practice/blob/main/Neuroscience/ALL_Online_lectures_attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
electro_nl = 'https://docs.google.com/spreadsheets/d/1843cEYKKW1m-NcXGFZ6SsjKB0WrNFiIYCf7z8HDE6mg/edit#gid=634790003'
electro_nl_url = electro_nl.replace('/edit#gid=', '/export?format=csv&gid=')

electro_l = 'https://docs.google.com/spreadsheets/d/1DM7HWozarErHE_7NeLFmMniBBr0E57mGjT3kssgHzKc/edit#gid=1722263721'
electro_l_url = electro_l.replace('/edit#gid=', '/export?format=csv&gid=')

grafen_nl = 'https://docs.google.com/spreadsheets/d/1wjCqUKtXB-yod-71Xru29mWCT9Wav6OBn5cPc1IAfi8/edit#gid=1557025172'
grafen_nl_url = grafen_nl.replace('/edit#gid=', '/export?format=csv&gid=')

grafen_l = 'https://docs.google.com/spreadsheets/d/1wAFMQZjOkyNHI1jaiWtcUkp7rGiwtCQN07SL2IBTUKw/edit#gid=1582245011'
grafen_l_url = grafen_l.replace('/edit#gid=', '/export?format=csv&gid=')

# %%
df_enu1 = pd.read_csv(electro_nl_url)
df_enu1["lector_flag"] = 'nl'

df_el1 = pd.read_csv(electro_l_url)
df_el1["lector_flag"] = 'l'

df_enu1['Баллы'] = df_enu1['Баллы'].apply(lambda x: int(x.replace('/ 6', '')))
df_el1['Баллы'] = df_el1['Баллы'].apply(lambda x: int(x.replace('/ 6', '')))

df_enu2 = pd.read_csv(grafen_nl_url)
df_enu2["lector_flag"] = 'nl'

df_el2 = pd.read_csv(grafen_l_url)
df_el2["lector_flag"] = 'l'

df_enu2['Баллы'] = df_enu2['Баллы'].apply(lambda x: int(x.replace('/ 5', '')))
df_el2['Баллы'] = df_el2['Баллы'].apply(lambda x: int(x.replace('/ 5', '')))

# %%
df = pd.concat([df_enu1, df_el1, df_enu2, df_el2], ignore_index=True)
df.head()
# Out:
#        Отметка времени  Баллы Ваш ID  \
# 0  30.03.2023 14:12:12      3    2.1
# 1  30.03.2023 17:35:13      5    2.2
# 2  31.03.2023 13:36:20      3    2.3
# 3  31.03.2023 15:02:03      2    2.4
# 4  31.03.2023 16:23:49      2    2.5
#
#    На сколько блоков можно разделить систему электроснабжения?  \
# 0                                                3.0
# 1                                                3.0
# 2                                                3.0
# 3                                                4.0
# 4                                                3.0
#
#                    Что такое линия передач?  \
# 0  Один из способов передачи электроэнергии
# 1  Один из способов передачи электроэнергии
# 2  Один из способов передачи электроэнергии
# 3  Один из способов передачи электроэнергии
# 4  Один из способов передачи электроэнергии
#
#   Выберите все верные утверждения (речь именно о Якутии)  \
# 0                                           Не помню
# 1                      На проводах зимой бывает снег
# 2             На проводах зимой бывает лед, Не помню
# 3                                           Не помню
# 4                                           Не помню
#
#   Какие опоры наиболее популярны? (в Якутии)  \
# 0                                 Деревянные
# 1                                 Деревянные
# 2                                 Деревянные
# 3                                 Деревянные
# 4                            Железо-бетонные
#
#   Где находился логотип во время всей лекции?  Оцените лектора  \
# 0                            Логотипа не было                2
# 1                                      Справа                3
# 2                                       Слева                3
# 3                            Логотипа не было                4
# 4                            Логотипа не было                3
#
#    Оцените качество презентации (слайды)  Оцените лекцию в целом  \
# 0                                      1                       3
# 1                                      3                       4
# 2                                      2                       2
# 3                                      1                       3
# 4                                      3                       4
#
#               Что бы вам хотелось изменить в лекции? lector_flag  \
# 0  дизайн (ВЕСЬ), лектора домой, слайд с тетькой ...          nl
# 1                                                  -          nl
# 2                                    Поживее дикцию           nl
# 3  Более интерактивные изображения, улучшить каче...          nl
# 4                  Картинки более высокого качества           nl
#
#   Выберите все верные утверждения  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#   С помощью чего доказали существование графена? Физический аналог графена  \
# 0                                            NaN                       NaN
# 1                                            NaN                       NaN
# 2                                            NaN                       NaN
# 3                                            NaN                       NaN
# 4                                            NaN                       NaN
#
#   Прочен ли графен? Выберите верные утверждения
# 0               NaN                         NaN
# 1               NaN                         NaN
# 2               NaN                         NaN
# 3               NaN                         NaN
# 4               NaN                         NaN

# %%
df = df.rename(columns={"Отметка времени": "time",
                    "Ваш ID": "id", "Баллы": "points", 
                    "На сколько блоков можно разделить систему электроснабжения?": "Q1_blocks", 
                    "Что такое линия передач?": "Q2_line", 
                    "Выберите все верные утверждения (речь именно о Якутии)": "Q3_ice", 
                    "Какие опоры наиболее популярны? (в Якутии)": "Q4_supports", 
                    "Где находился логотип во время всей лекции?": "Q5_logo",
                    "Оцените лектора": "Lector_rate",
                    "Оцените качество презентации (слайды)": "Slide_rate",
                    "Оцените лекцию в целом": "General_rate",
                    "Что бы вам хотелось изменить в лекции?": "Comment"})
df.head(1)
# Out:
#                   time  points   id  Q1_blocks  \
# 0  30.03.2023 14:12:12       3  2.1        3.0
#
#                                     Q2_line    Q3_ice Q4_supports  \
# 0  Один из способов передачи электроэнергии  Не помню  Деревянные
#
#             Q5_logo  Lector_rate  Slide_rate  General_rate  \
# 0  Логотипа не было            2           1             3
#
#                                              Comment lector_flag  \
# 0  дизайн (ВЕСЬ), лектора домой, слайд с тетькой ...          nl
#
#   Выберите все верные утверждения  \
# 0                             NaN
#
#   С помощью чего доказали существование графена? Физический аналог графена  \
# 0                                            NaN                       NaN
#
#   Прочен ли графен? Выберите верные утверждения
# 0               NaN                         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 18 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   time                                            28 non-null     object
#  1   points                                          28 non-null     int64
#  2   id                                              28 non-null     object
#  3   Q1_blocks                                       14 non-null     float64
#  4   Q2_line                                         14 non-null     object
#  5   Q3_ice                                          14 non-null     object
#  6   Q4_supports                                     14 non-null     object
#  7   Q5_logo                                         14 non-null     object
#  8   Lector_rate                                     28 non-null     int64
#  9   Slide_rate                                      28 non-null     int64
#  10  General_rate                                    28 non-null     int64
#  11  Comment                                         25 non-null     object
#  12  lector_flag                                     28 non-null     object
#  13  Выберите все верные утверждения                 14 non-null     object
#  14  С помощью чего доказали существование графена?  14 non-null     object
#  15  Физический аналог графена                       14 non-null     object
#  16  Прочен ли графен?                               14 non-null     object
#  17  Выберите верные утверждения                     14 non-null     object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 4.1+ KB

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.hist([df[df.lector_flag=='l'].points, df[df.lector_flag=='nl'].points], 
        edgecolor='black', color=['b', 'r'], 
        label=['lector', 'no lector'],alpha=0.8, bins=range(1, 7), align='left')
plt.xticks(range(1, 6))
plt.yticks(range(0, 5))
plt.xlim([0, 6])
plt.legend(loc='upper right')
plt.title('Распределение по баллом участников за обе лекции')
plt.ylabel('Количество участников')
plt.xlabel('Баллы за тест')

plt.subplot(1, 2, 2)
sns.barplot(data=df, x='lector_flag', y=df.points, errorbar=None, palette = ['b', 'r'])
plt.title("Средние баллы участников")
plt.ylabel("Баллы участников")
plt.xlabel("Лектор(l), без лектора(nl)")
# Out:
# Text(0.5, 0, 'Лектор(l), без лектора(nl)')

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.hist([df[df.lector_flag=='l'].Lector_rate, df[df.lector_flag=='nl'].Lector_rate], 
        edgecolor='black', color=['b', 'r'], 
        label=['lector', 'no lector'],alpha=0.8, bins=range(1, 7), align='left')
plt.xticks(range(1, 6))
plt.yticks(range(0, 5))
plt.xlim([0, 6])
plt.legend(loc='upper right')
plt.title('Распределение по рейтингу лектора за обе лекции')
plt.ylabel('Количество участников')
plt.xlabel('Рейтинг лектора')

plt.subplot(1, 2, 2)
sns.barplot(data=df, x='lector_flag', y=df.Lector_rate, errorbar=None, palette = ['b', 'r'])
plt.title("Средние оценки лектора")
plt.ylabel("Оценка лектора")
plt.xlabel("Лектор(l), без лектора(nl)")
# Out:
# Text(0.5, 0, 'Лектор(l), без лектора(nl)')

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.hist([df[df.lector_flag=='l'].General_rate, df[df.lector_flag=='nl'].General_rate], 
        edgecolor='black', color=['b', 'r'], 
        label=['lector', 'no lector'],alpha=0.8, bins=range(1, 7), align='left')
plt.xticks(range(1, 6))
plt.yticks(range(0, 5))
plt.xlim([0, 6])
plt.legend(loc='upper right')
plt.title('Распределение по рейтингу лекции в целом за обе лекции')
plt.ylabel('Количество участников')
plt.xlabel('Рейтинг лекции в целом')

plt.subplot(1, 2, 2)
sns.barplot(data=df, x='lector_flag', y=df.General_rate, errorbar=None, palette = ['b', 'r'])
plt.title("Средние оценки лекции в целом")
plt.ylabel("Оценка лектора")
plt.xlabel("Лектор(l), без лектора(nl)")
# Out:
# Text(0.5, 0, 'Лектор(l), без лектора(nl)')

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.hist([df[df.lector_flag=='l'].Slide_rate, df[df.lector_flag=='nl'].Slide_rate], 
        edgecolor='black', color=['b', 'r'], 
        label=['lector', 'no lector'],alpha=0.8, bins=range(1, 7), align='left')
plt.xticks(range(1, 6))
plt.yticks(range(0, 5))
plt.xlim([0, 6])
plt.legend(loc='upper right')
plt.title('Распределение по рейтингу слайдов за обе лекции')
plt.ylabel('Количество участников')
plt.xlabel('Рейтинг слайдов')

plt.subplot(1, 2, 2)
sns.barplot(data=df, x='lector_flag', y=df.Slide_rate, errorbar=None, palette = ['b', 'r'])
plt.title("Средние оценки слайдов")
plt.ylabel("Оценка слайдов")
plt.xlabel("Лектор(l), без лектора(nl)")
# Out:
# Text(0.5, 0, 'Лектор(l), без лектора(nl)')

# %%
df.drop(columns='Q1_blocks').corr()
# Out:
#                 points  Lector_rate  Slide_rate  General_rate
# points        1.000000    -0.166754    0.012606      0.018870
# Lector_rate  -0.166754     1.000000    0.553225      0.593706
# Slide_rate    0.012606     0.553225    1.000000      0.530281
# General_rate  0.018870     0.593706    0.530281      1.000000
